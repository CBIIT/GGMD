# %%
import pandas as pd

# %%
df = pd.read_csv("/mnt/projects/ATOM/blackst/FNLGMD/examples/LogP_JTVAE/data_all_generations.csv")
df
# Out:
#     compound_id                                             smiles   fitness  \
# 0             0  COC(=O)c1cc2n(n1)CCCN(C(=O)c1ccc(-c3ncn[nH]3)c... -4.854995
# 1             1  Cc1ccc([N+](=O)[O-])cc1NC(=O)C(=O)NC[C@@H](c1c... -2.431173
# 2             2      Cc1ccc(C2=N/C(=C3/C=CC=CC3=O)N(O)[C@@H]2C)cc1  0.289684
# 3             3  COc1cccc(CNC(=O)C[C@H]2CCCCN2S(=O)(=O)c2ccc(F)...  1.547098
# 4             4  CC(=O)Oc1ccc(/C=C2\N=C(c3ccc(-c4ccccc4)cc3)OC2...  2.790013
# ..          ...                                                ...       ...
# 84           84                  Nc1cccc(-c2ccc(-c3ccccc3)nc2Br)c1  2.394538
# 85           85            N#Cc1ccc(OCC(=O)Nc2cccc(-c3cccs3)c2)cc1  2.189258
# 86           86                [NH3+]C1(C(=O)NCCc2ccc(Cl)s2)CCCCC1 -0.476568
# 87           87    O=C(c1ccccn1)N(Cc1ccc([N+](=O)[O-])cc1)C1CCCCC1  1.792642
# 88           88                COC(=O)C=Cc1cnc(NC2CC3CCC2(C)C3)nc1 -1.493144
#
# ...

# %%
df['fitness'].idxmin(), df['fitness'].idxmax()
# Out:
# (27, 63)
