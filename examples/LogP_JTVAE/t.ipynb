# %%
import pandas as pd

# %%
df = pd.read_csv("/mnt/projects/ATOM/blackst/FNLGMD/workspace/example_dir/data_all_generations.csv")
df
# Out:
#     compound_id                                             smiles   fitness  \
# 0             0             CCC[C@H]1CCC[C@](O)(Cc2[nH+]ccn2CC)CC1 -4.954130
# 1             1      CC1(C)[C@H]2CN(C(=O)[C@@H]3CSC(=O)N3)C[C@H]21 -2.069843
# 2             2              Cc1csc(CCCNC(=O)C2=Cc3cc(F)ccc3OC2)n1  1.492618
# 3             3        NC(=O)c1cccc(S(=O)(=O)[N-]c2cc(F)cc(F)c2)c1  0.311596
# 4             4  CC[C@H]([NH3+])Cc1ccc(N2C[C@@H](C)[C@@H](C)C2)cc1 -0.607744
# ..          ...                                                ...       ...
# 78           78       COC(NC(=O)c1ccc(NS(=O)(=O)c2ccccc2)cc1)C(C)N -0.204749
# 79           79           CSc1ccc(C(=O)N2CC=CC34C=CC=CC23NC=N4)cc1 -1.937247
# 80           80                Cc1cc(C)c2c(c1)OC(C)(c1cc(Cl)on1)O2 -0.182729
# 81           81         CCOC(=O)C12SC(c3ccc(C4CC4)cc3)NC1(C)NN=C2C -1.544296
# 82           82    COc1ccc(C(C)(C)CNC(=O)N2CC[NH2+]C(CC(C)O)C2)cc1 -2.456102
#
#     generation                                         chromosome  parent1_id  \
# 0            0  [-0.9082487   0.3288781  -1.6749098   0.677304...         NaN
# 1            0  [ 0.16142216  0.39077467  0.25625512 -0.253218...         NaN
# 2            0  [ 6.59751594e-01 -2.63889730e-02 -4.94204521e-...         NaN
# 3            0  [ 6.8039918e-01  3.1967714e-01  8.6287928e-01 ...         NaN
# 4            0  [ 2.255765   -1.871867   -1.173696   -1.950641...         NaN
# ..         ...                                                ...         ...
# 78           2  [ 0.5298224  -2.1019275   1.3141251   0.454394...        38.0
# 79           2  [ 6.80399179e-01  3.19677144e-01  5.40761709e-...        22.0
# 80           2  [-3.35867524e-01 -1.80015206e+00  6.26120389e-...         9.0
# 81           2  [-7.22128510e-01 -6.30506635e-01 -2.85201597e+...        56.0
# 82           2  [-1.6990632  -0.13203728  0.96616346 -3.026548...        41.0
#
#     parent2_id
# 0          NaN
# 1          NaN
# 2          NaN
# 3          NaN
# 4          NaN
# ..         ...
# 78        51.0
# 79         3.0
# 80        50.0
# 81         8.0
# 82        12.0
#
# [83 rows x 7 columns]

# %%
df['fitness'].idxmin(), df['fitness'].idxmax()
# Out:
# (0, 49)
